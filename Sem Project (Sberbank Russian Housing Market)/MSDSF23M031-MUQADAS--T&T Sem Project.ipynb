# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Load the dataset
data = pd.read_csv('train_without_noise.csv')

# %%
# B. Data Cleaning and Preprocessing:
# Handle missing data
data.dropna(inplace=True)


# Detect and address outliers or anomalies
sns.boxplot(x=data['full_sq'])
plt.show()

# Address outliers by removing or replacing them
num_rows = len(data.index)
low_information_cols = []

for col in data.columns:
    cnts = data[col].value_counts(dropna=False)
    top_pct = (cnts/num_rows).iloc[0]
    
    if top_pct > 0.95:
        low_information_cols.append(col)
        print('{0}:{1:.5f}%'.format(col,top_pct*100))
        print(cnts)
        print()
# Out:
# product_type:95.56492%
# product_type
# Investment       5667
# OwnerOccupier     263
# Name: count, dtype: int64
#
# incineration_raion:100.00000%
# incineration_raion
# no    5930
# Name: count, dtype: int64
#
# oil_chemistry_raion:97.52108%
# oil_chemistry_raion
# no     5783
# yes     147
# Name: count, dtype: int64
#
# big_market_raion:97.16695%
# big_market_raion
# no     5762
# yes     168
# Name: count, dtype: int64
#
# build_count_foam:95.91906%
# build_count_foam
# 0.0     5688
# 11.0     148
# 2.0       86
# 1.0        8
# Name: count, dtype: int64
#
# water_1line:95.37943%
# water_1line
# no     5656
# yes     274
# Name: count, dtype: int64
#
# big_road1_1line:96.20573%
# big_road1_1line
# no     5705
# yes     225
# Name: count, dtype: int64
#
# railroad_1line:97.08263%
# railroad_1line
# no     5757
# yes     173
# Name: count, dtype: int64
#
# cafe_count_500_price_high:95.66610%
# cafe_count_500_price_high
# 0    5673
# 1     229
# 2      19
# 3       9
# Name: count, dtype: int64
#
# mosque_count_500:99.49410%
# mosque_count_500
# 0    5900
# 1      30
# Name: count, dtype: int64
#
# mosque_count_1000:97.75717%
# mosque_count_1000
# 0    5797
# 1     133
# Name: count, dtype: int64
#
# mosque_count_1500:95.26138%
# mosque_count_1500
# 0    5649
# 1     281
# Name: count, dtype: int64
#
# sub_area_Ajeroport:98.90388%
# sub_area_Ajeroport
# False    5865
# True       65
# Name: count, dtype: int64
#
# sub_area_Akademicheskoe:97.80776%
# sub_area_Akademicheskoe
# False    5800
# True      130
# Name: count, dtype: int64
#
# sub_area_Alekseevskoe:99.03879%
# sub_area_Alekseevskoe
# False    5873
# True       57
# Name: count, dtype: int64
#
# sub_area_Arbat:99.89882%
# sub_area_Arbat
# False    5924
# True        6
# Name: count, dtype: int64
#
# sub_area_Babushkinskoe:98.98820%
# sub_area_Babushkinskoe
# False    5870
# True       60
# Name: count, dtype: int64
#
# sub_area_Basmannoe:99.03879%
# sub_area_Basmannoe
# False    5873
# True       57
# Name: count, dtype: int64
#
# sub_area_Begovoe:99.42664%
# sub_area_Begovoe
# False    5896
# True       34
# Name: count, dtype: int64
#
# sub_area_Beskudnikovskoe:98.44857%
# sub_area_Beskudnikovskoe
# False    5838
# True       92
# Name: count, dtype: int64
#
# sub_area_Bibirevo:98.14503%
# sub_area_Bibirevo
# False    5820
# True      110
# Name: count, dtype: int64
#
# sub_area_Birjulevo Vostochnoe:98.29680%
# sub_area_Birjulevo Vostochnoe
# False    5829
# True      101
# Name: count, dtype: int64
#
# sub_area_Caricyno:98.95447%
# sub_area_Caricyno
# False    5868
# True       62
# Name: count, dtype: int64
#
# sub_area_Cheremushki:98.49916%
# sub_area_Cheremushki
# False    5841
# True       89
# Name: count, dtype: int64
#
# sub_area_Danilovskoe:98.11130%
# sub_area_Danilovskoe
# False    5818
# True      112
# Name: count, dtype: int64
#
# sub_area_Dmitrovskoe:98.53288%
# sub_area_Dmitrovskoe
# False    5843
# True       87
# Name: count, dtype: int64
#
# sub_area_Donskoe:98.93761%
# sub_area_Donskoe
# False    5867
# True       63
# Name: count, dtype: int64
#
# sub_area_Filevskij Park:98.44857%
# sub_area_Filevskij Park
# False    5838
# True       92
# Name: count, dtype: int64
#
# sub_area_Gol'janovo:97.41990%
# sub_area_Gol'janovo
# False    5777
# True      153
# Name: count, dtype: int64
#
# sub_area_Golovinskoe:98.17875%
# sub_area_Golovinskoe
# False    5822
# True      108
# Name: count, dtype: int64
#
# sub_area_Hamovniki:99.13997%
# sub_area_Hamovniki
# False    5879
# True       51
# Name: count, dtype: int64
#
# sub_area_Horoshevo-Mnevniki:97.50422%
# sub_area_Horoshevo-Mnevniki
# False    5782
# True      148
# Name: count, dtype: int64
#
# sub_area_Hovrino:98.53288%
# sub_area_Hovrino
# False    5843
# True       87
# Name: count, dtype: int64
#
# sub_area_Izmajlovo:98.16189%
# sub_area_Izmajlovo
# False    5821
# True      109
# Name: count, dtype: int64
#
# sub_area_Jakimanka:99.20742%
# sub_area_Jakimanka
# False    5883
# True       47
# Name: count, dtype: int64
#
# sub_area_Jaroslavskoe:99.35919%
# sub_area_Jaroslavskoe
# False    5892
# True       38
# Name: count, dtype: int64
#
# sub_area_Jasenevo:98.73524%
# sub_area_Jasenevo
# False    5855
# True       75
# Name: count, dtype: int64
#
# sub_area_Juzhnoe Medvedkovo:99.08938%
# sub_area_Juzhnoe Medvedkovo
# False    5876
# True       54
# Name: count, dtype: int64
#
# sub_area_Juzhnoportovoe:99.05565%
# sub_area_Juzhnoportovoe
# False    5874
# True       56
# Name: count, dtype: int64
#
# sub_area_Kapotnja:99.91568%
# sub_area_Kapotnja
# False    5925
# True        5
# Name: count, dtype: int64
#
# sub_area_Kon'kovo:97.92580%
# sub_area_Kon'kovo
# False    5807
# True      123
# Name: count, dtype: int64
#
# sub_area_Koptevo:98.24621%
# sub_area_Koptevo
# False    5826
# True      104
# Name: count, dtype: int64
#
# sub_area_Krjukovo:99.86509%
# sub_area_Krjukovo
# False    5922
# True        8
# Name: count, dtype: int64
#
# sub_area_Kuncevo:98.54975%
# sub_area_Kuncevo
# False    5844
# True       86
# Name: count, dtype: int64
#
# sub_area_Kurkino:99.54469%
# sub_area_Kurkino
# False    5903
# True       27
# Name: count, dtype: int64
#
# sub_area_Lefortovo:98.90388%
# sub_area_Lefortovo
# False    5865
# True       65
# Name: count, dtype: int64
#
# sub_area_Levoberezhnoe:98.80270%
# sub_area_Levoberezhnoe
# False    5859
# True       71
# Name: count, dtype: int64
#
# sub_area_Ljublino:98.19562%
# sub_area_Ljublino
# False    5823
# True      107
# Name: count, dtype: int64
#
# sub_area_Lomonosovskoe:98.56661%
# sub_area_Lomonosovskoe
# False    5845
# True       85
# Name: count, dtype: int64
#
# sub_area_Losinoostrovskoe:99.15683%
# sub_area_Losinoostrovskoe
# False    5880
# True       50
# Name: count, dtype: int64
#
# sub_area_Mar'ina Roshha:98.97133%
# sub_area_Mar'ina Roshha
# False    5869
# True       61
# Name: count, dtype: int64
#
# sub_area_Meshhanskoe:99.17369%
# sub_area_Meshhanskoe
# False    5881
# True       49
# Name: count, dtype: int64
#
# sub_area_Moskvorech'e-Saburovo:99.35919%
# sub_area_Moskvorech'e-Saburovo
# False    5892
# True       38
# Name: count, dtype: int64
#
# sub_area_Mozhajskoe:98.14503%
# sub_area_Mozhajskoe
# False    5820
# True      110
# Name: count, dtype: int64
#
# sub_area_Nagatino-Sadovniki:98.46543%
# sub_area_Nagatino-Sadovniki
# False    5839
# True       91
# Name: count, dtype: int64
#
# sub_area_Nagatinskij Zaton:98.80270%
# sub_area_Nagatinskij Zaton
# False    5859
# True       71
# Name: count, dtype: int64
#
# sub_area_Novo-Peredelkino:99.15683%
# sub_area_Novo-Peredelkino
# False    5880
# True       50
# Name: count, dtype: int64
#
# sub_area_Novogireevo:98.27993%
# sub_area_Novogireevo
# False    5828
# True      102
# Name: count, dtype: int64
#
# sub_area_Obruchevskoe:98.70152%
# sub_area_Obruchevskoe
# False    5853
# True       77
# Name: count, dtype: int64
#
# sub_area_Ochakovo-Matveevskoe:99.64587%
# sub_area_Ochakovo-Matveevskoe
# False    5909
# True       21
# Name: count, dtype: int64
#
# sub_area_Ostankinskoe:99.24115%
# sub_area_Ostankinskoe
# False    5885
# True       45
# Name: count, dtype: int64
#
# sub_area_Pechatniki:98.68465%
# sub_area_Pechatniki
# False    5852
# True       78
# Name: count, dtype: int64
#
# sub_area_Perovo:97.60540%
# sub_area_Perovo
# False    5788
# True      142
# Name: count, dtype: int64
#
# sub_area_Pokrovskoe Streshnevo:98.75211%
# sub_area_Pokrovskoe Streshnevo
# False    5856
# True       74
# Name: count, dtype: int64
#
# sub_area_Preobrazhenskoe:98.66779%
# sub_area_Preobrazhenskoe
# False    5851
# True       79
# Name: count, dtype: int64
#
# sub_area_Presnenskoe:97.97639%
# sub_area_Presnenskoe
# False    5810
# True      120
# Name: count, dtype: int64
#
# sub_area_Prospekt Vernadskogo:99.17369%
# sub_area_Prospekt Vernadskogo
# False    5881
# True       49
# Name: count, dtype: int64
#
# sub_area_Ramenki:98.46543%
# sub_area_Ramenki
# False    5839
# True       91
# Name: count, dtype: int64
#
# sub_area_Rostokino:99.46037%
# sub_area_Rostokino
# False    5898
# True       32
# Name: count, dtype: int64
#
# sub_area_Savelki:99.54469%
# sub_area_Savelki
# False    5903
# True       27
# Name: count, dtype: int64
#
# sub_area_Savelovskoe:99.02192%
# sub_area_Savelovskoe
# False    5872
# True       58
# Name: count, dtype: int64
#
# sub_area_Severnoe:99.89882%
# sub_area_Severnoe
# False    5924
# True        6
# Name: count, dtype: int64
#
# sub_area_Severnoe Butovo:98.33052%
# sub_area_Severnoe Butovo
# False    5831
# True       99
# Name: count, dtype: int64
#
# sub_area_Severnoe Tushino:98.29680%
# sub_area_Severnoe Tushino
# False    5829
# True      101
# Name: count, dtype: int64
#
# sub_area_Shhukino:98.38111%
# sub_area_Shhukino
# False    5834
# True       96
# Name: count, dtype: int64
#
# sub_area_Sokol:99.12310%
# sub_area_Sokol
# False    5878
# True       52
# Name: count, dtype: int64
#
# sub_area_Sokol'niki:99.42664%
# sub_area_Sokol'niki
# False    5896
# True       34
# Name: count, dtype: int64
#
# sub_area_Sokolinaja Gora:98.78583%
# sub_area_Sokolinaja Gora
# False    5858
# True       72
# Name: count, dtype: int64
#
# sub_area_Solncevo:99.24115%
# sub_area_Solncevo
# False    5885
# True       45
# Name: count, dtype: int64
#
# sub_area_Sviblovo:99.05565%
# sub_area_Sviblovo
# False    5874
# True       56
# Name: count, dtype: int64
#
# sub_area_Taganskoe:98.11130%
# sub_area_Taganskoe
# False    5818
# True      112
# Name: count, dtype: int64
#
# sub_area_Tekstil'shhiki:98.21248%
# sub_area_Tekstil'shhiki
# False    5824
# True      106
# Name: count, dtype: int64
#
# sub_area_Timirjazevskoe:98.66779%
# sub_area_Timirjazevskoe
# False    5851
# True       79
# Name: count, dtype: int64
#
# sub_area_Tverskoe:96.98145%
# sub_area_Tverskoe
# False    5751
# True      179
# Name: count, dtype: int64
#
# sub_area_Veshnjaki:98.39798%
# sub_area_Veshnjaki
# False    5835
# True       95
# Name: count, dtype: int64
#
# sub_area_Vnukovo:99.89882%
# sub_area_Vnukovo
# False    5924
# True        6
# Name: count, dtype: int64
#
# sub_area_Vostochnoe Izmajlovo:98.65093%
# sub_area_Vostochnoe Izmajlovo
# False    5850
# True       80
# Name: count, dtype: int64
#
# sub_area_Vyhino-Zhulebino:98.29680%
# sub_area_Vyhino-Zhulebino
# False    5829
# True      101
# Name: count, dtype: int64
#
# sub_area_Zamoskvorech'e:99.54469%
# sub_area_Zamoskvorech'e
# False    5903
# True       27
# Name: count, dtype: int64
#
# sub_area_Zapadnoe Degunino:98.93761%
# sub_area_Zapadnoe Degunino
# False    5867
# True       63
# Name: count, dtype: int64
#
# sub_area_Zjablikovo:99.29174%
# sub_area_Zjablikovo
# False    5888
# True       42
# Name: count, dtype: int64
#
# sub_area_Zjuzino:97.63912%
# sub_area_Zjuzino
# False    5790
# True      140
# Name: count, dtype: int64

# %%
# C. Exploratory Data Analysis (EDA):
# Conduct statistical analysis
data.describe()
# Out:
#                  id      full_sq      life_sq        floor    max_floor  \
# count   5930.000000  5930.000000  5930.000000  5930.000000  5930.000000
# mean   19867.174368    53.099831    32.859191     6.517538    11.706914
# std     6078.412892    23.818362    18.847648     4.846970     6.078652
# min     8059.000000     1.000000     1.000000     0.000000     1.000000
# 25%    14605.250000    38.000000    20.000000     3.000000     8.000000
# 50%    19895.500000    46.000000    29.000000     5.000000    10.000000
# 75%    25175.750000    62.000000    41.000000     9.000000    16.000000
# max    30473.000000   637.000000   637.000000    44.000000    48.000000
#
#           material   build_year     num_room     kitch_sq        state  ...  \
# count  5930.000000  5930.000000  5930.000000  5930.000000  5930.000000  ...
# mean      2.054132  1958.153457     1.998651     7.397133     2.418212  ...
# std       1.496024   199.354300     0.889775     3.352103     0.780608  ...
# min       1.000000     0.000000     0.000000     0.000000     1.000000  ...
# 25%       1.000000  1964.000000     1.000000     5.000000     2.000000  ...
# 50%       1.000000  1971.000000     2.000000     7.000000     2.000000  ...
# 75%       2.000000  1989.000000     3.000000     9.000000     3.000000  ...
# max       6.000000  4965.000000    17.000000    96.000000    33.000000  ...
#
#        cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# count                 5930.000000                 5930.000000
# mean                    61.679258                   21.197976
# std                     94.297642                   37.257025
# min                      0.000000                    0.000000
# 25%                      9.000000                    2.000000
# 50%                     21.000000                    4.000000
# 75%                     54.750000                   14.000000
# max                    376.000000                  146.000000
#
#        cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# count                 5930.000000            5930.000000        5930.000000
# mean                     3.547218              27.326644          50.656830
# std                      7.168564              37.310543          59.824369
# min                      0.000000               1.000000           2.000000
# 25%                      0.000000               8.000000          17.000000
# 50%                      0.000000              11.000000          27.000000
# 75%                      2.000000              23.000000          46.000000
# max                     29.000000             151.000000         250.000000
#
#        mosque_count_5000  leisure_count_5000  sport_count_5000  \
# count        5930.000000         5930.000000       5930.000000
# mean            0.632209           16.620405         84.669983
# std             0.678669           26.458669         43.708230
# min             0.000000            0.000000          0.000000
# 25%             0.000000            2.000000         55.000000
# 50%             1.000000            6.000000         75.000000
# 75%             1.000000           12.000000        105.750000
# max             2.000000          106.000000        215.000000
#
#        market_count_5000     price_doc
# count        5930.000000  5.930000e+03
# mean            9.036594  8.680761e+06
# std             4.188771  6.230094e+06
# min             0.000000  5.000000e+05
# 25%             5.000000  5.800000e+06
# 50%            10.000000  7.350000e+06
# 75%            12.000000  1.040000e+07
# max            20.000000  9.512250e+07
#
# [8 rows x 276 columns]

# %%
# D. Data Visualization:
# Histogram of 'full_sq'
sns.histplot(data['full_sq'], bins=20)
plt.show()

# %%
# Box plot of 'price_doc' vs 'num_room'
sns.boxplot(y='price_doc', x='num_room', data=data)
plt.show()

# %%
# Scatter plot of 'life_sq' vs 'price_doc'
sns.scatterplot(x='life_sq', y='price_doc', data=data)
plt.show()

# %%
# E. Hypothesis Testing:
# Null Hypothesis: There is no significant difference in 'price_doc' between houses with different 'material'.
# Alternative Hypothesis: There is a significant difference in 'price_doc' between houses with different 'material'.
material_1 = data[data['material'] == 1]['price_doc']
material_2 = data[data['material'] == 2]['price_doc']

t_statistic, p_value = ttest_ind(material_1, material_2)
# Out:
# T-Statistic: -8.670654310454198
# P-Value: 5.819967910830365e-18
